# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
URL = "https://www.indiavotes.com/vidhan-sabha/2019/andhra-pradesh%20[2014%20onwards]/272/62"
page = requests.get(URL)
print(page.text)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
#
# <link type="image/x-icon" href="/favicon.ico" rel="shortcut icon">
# <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=yes">
# <title> IndiaVotes AC: Andhra Pradesh [2014 Onwards] 2019 </title>
# <meta property="fb:app_id" content="490449004322287" />
# <meta property="og:description" content=" IndiaVotes AC: Andhra Pradesh [2014 Onwards] 2019 " />
# <meta property="title" content="2019 Vidhan Sabha election results Andhra Pradesh [2014 Onwards]" />
# <meta property="description" content="2019 Vidhan Sabha election results Andhra Pradesh [2014 Onwards] | Winning party Yuvajana Sramika Rythu Congress Party - seats 151, Runnerup Party Telugu Desam - seats 23" />
# <meta property="og:image" content="https://www.indiavotes.com/images/indiavotescom_200X200.jpg" />
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(page.content,'html.parser')

# %%
pip install HTMLParser
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for HTMLParser: filename=HTMLParser-0.0.2-py3-none-any.whl size=5992 sha256=2bd1368a64766eddec758a151a0591b7d889be2818d11301546ca9ecf73661e9
#   Stored in directory: c:\users\vizag\appdata\local\pip\cache\wheels\72\b6\70\2f0e887b33d05a5c2522821395dc83029f2db5e01f003f7705
# Successfully built HTMLParser
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
#  <head>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=yes" name="viewport"/>
#   <title>
#    IndiaVotes AC: Andhra Pradesh [2014 Onwards] 2019
#   </title>
#   <meta content="490449004322287" property="fb:app_id">
#    <meta content=" IndiaVotes AC: Andhra Pradesh [2014 Onwards] 2019 " property="og:description"/>
#    <meta content="2019 Vidhan Sabha election results Andhra Pradesh [2014 Onwards]" property="title"/>
#    <meta content="2019 Vidhan Sabha election results Andhra Pradesh [2014 Onwards] | Winning party Yuvajana Sramika Rythu Congress Party - seats 151, Runnerup Party Telugu Desam - seats 23" property="description"/>
#    <meta content="https://www.indiavotes.com/images/indiavotescom_200X200.jpg" property="og:image"/>
# ...

# %%
print(soup.title)
# Out:
# <title> IndiaVotes AC: Andhra Pradesh [2014 Onwards] 2019 </title>

# %%
print(soup.title.name)
# Out:
# title

# %%
print(soup.title.string)
# Out:
#  IndiaVotes AC: Andhra Pradesh [2014 Onwards] 2019

# %%
print(soup.title.parent.string)
# Out:
# None

# %%
soup.p
# Out:
# <p><label class="fl"><b>Name</b></label><br/><input id="name" name="name" placeholder="Name" type="text"/></p>

# %%
soup.find_all('a')
# Out:
# [<a class="voteNitiLogo" href="https://www.indiavotes.com/" title="India votes"><img alt="India votes" src="https://www.indiavotes.com/images/india-votes.png" title="India votes"/></a>,
#  <a href="https://www.indiavotes.com/blog/feed/" target="_blank"><img alt="RSS FEED" src="https://www.indiavotes.com/images/rss.png" style="padding-right:5px;" title="RSS FEED"/></a>,
#  <a href="https://www.facebook.com/indiavotescom" target="_blank"><img alt=" Join Us on Facebook" src="https://www.indiavotes.com/images/fb-icon.png" style="padding-right:10px;" title="Join Us on Facebook"/></a>,
#  <a href="https://twitter.com/IndiaVotescom" target="_blank" title="India votes"><img alt="Follow Us on Twitter" src="https://www.indiavotes.com/images/twitter-icon.png" title="Follow Us on Twitter"/></a>,
#  <a id="menu-icon">☰</a>,
#  <a href="https://www.indiavotes.com/" title="Home">Home</a>,
#  <a href="https://www.indiavotes.com/home/about_us" title="About us">About Us</a>,
# ...

# %%
soup.find(id="mianContent")
# Out:
# <div class="mianContent" id="mianContent"></div>

# %%
soup.find_all('p')
# Out:
# [<p><label class="fl"><b>Name</b></label><br/><input id="name" name="name" placeholder="Name" type="text"/></p>,
#  <p><label class="fl"><b>Email<span class="mandatory">*</span></b></label><br/><input id="email" name="email" placeholder="Email" type="text"/></p>,
#  <p><label class="fl"><b>Page Url</b></label><br/>
#  <input class="errorLink" disabled="" type="text"/></p>,
#  <p><label class="fl"><b>Describe error</b></label><br/>
#  <textarea class="inputForm" id="description" name="description" placeholder="Describe error" rows="7"></textarea></p>,
#  <p><button class="g-recaptcha btn click_subt" data-callback="onSubmit" data-sitekey="6LcrydQaAAAAAKRQ20ag6kSpGFfbfUDw3u04nfMz" data-size="invisible">Submit</button></p>]

# %%
#to get all elements with specific tag(here li-list items)
soup.find_all('li')
# Out:
# [<li><a href="https://www.indiavotes.com/" title="Home">Home</a></li>,
#  <li><a href="https://www.indiavotes.com/home/about_us" title="About us">About Us</a></li>,
#  <li><a href="https://www.indiavotes.com/home/advanced_search" title="Search Filter">Search Filter</a></li>,
#  <li><a href="https://www.indiavotes.com/explore" title="Explore">Explore</a></li>,
#  <li><a href="https://www.indiavotes.com/summary" title="Summary Report">Summary Report</a></li>,
#  <li><a href="#reportError" name="modal" title="Report Errors">Report Errors</a></li>]

# %%
#to get all reference links in the webpage
for l in soup.find_all('a'):
    print(l.get('href'))
# Out:
# https://www.indiavotes.com/
# https://www.indiavotes.com/blog/feed/
# https://www.facebook.com/indiavotescom
# https://twitter.com/IndiaVotescom
# None
# https://www.indiavotes.com/
# https://www.indiavotes.com/home/about_us
# https://www.indiavotes.com/home/advanced_search
# https://www.indiavotes.com/explore
# https://www.indiavotes.com/summary
# #reportError
# https://www.indiavotes.com/
# https://www.indiavotes.com/home/about_us
# https://www.indiavotes.com/blog/
# https://www.indiavotes.com/home/disclaimer
# #
# #

# %%
#to get the text in webpage
print(soup.get_text())
# Out:
#  IndiaVotes AC: Andhra Pradesh [2014 Onwards] 2019
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ☰
#
#
# Home
# About Us
# Search Filter
# Explore
# Summary Report
# Report Errors
#
#
#
#
#
#
#
#
#
#
#  2019 Vidhan Sabha / Assembly election results Andhra Pradesh [2014 Onwards]
#
#
#
#
#
#
# Home |
# About Us |
# Blog |
#
# Disclaimer
#
#
#
#
# Close
#
#
#
#
#
#
#
#
#
# Close
# Report Errors
#
#
# Name
# Email*
# Page Url
#
#
#
# Describe error
#
#
# Submit

# %%
soup.find("table").find("tbody").find_all("tr")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 soup.find("table").find("tbody").find_all("tr")
#
# AttributeError: 'NoneType' object has no attribute 'find'
