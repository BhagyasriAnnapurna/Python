# %%
from selenium import webdriver
import pandas as pd

# %%
driver=webdriver.Chrome()
driver.get('https://www.worldometers.info/world-population/population-by-country/')

# %%
countries=driver.find_elements("xpath",'//tbody/tr/td[2]/a')
population=driver.find_elements("xpath",'//tbody/tr/td[3]')
yearly_change=driver.find_elements("xpath",'//tbody/tr/td[4]')
world_share=driver.find_elements("xpath",'//tbody/tr/td[12]')


population_result=[]

for i in range(len(yearly_change)):
    temporary_data={'Country': countries[i].text,
                   'Population': population[i].text,
                   'Yearly Change': yearly_change[i].text,
                   'World Share': world_share[i].text}
    population_result.append(temporary_data)

# %%
df_data=pd.DataFrame(population_result)
df_data
# Out:
#               Country     Population Yearly Change World Share
# 0               India  1,428,627,663        0.81 %     17.76 %
# 1               China  1,425,671,352       -0.02 %     17.72 %
# 2       United States    339,996,563        0.50 %      4.23 %
# 3           Indonesia    277,534,122        0.74 %      3.45 %
# 4            Pakistan    240,485,658        1.98 %      2.99 %
# ..                ...            ...           ...         ...
# 229        Montserrat          4,386       -0.09 %      0.00 %
# 230  Falkland Islands          3,791        0.29 %      0.00 %
# 231              Niue          1,935        0.05 %      0.00 %
# 232           Tokelau          1,893        1.18 %      0.00 %
# 233          Holy See            518        1.57 %      0.00 %
#
# [234 rows x 4 columns]
